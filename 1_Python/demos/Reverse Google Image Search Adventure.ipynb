# %%
import requests

# %%
url = 'https://www.google.com/searchbyimage?%'
hardurl = 'https://www.google.com/searchbyimage?&image_url=http://i.imgur.com/njJkLm1.png'
params = {'image_url':'http://imgur.com/njJkLm1'}

# %%
r = requests.get(url=hardurl, params=params)

# %%
'guess' in r.text
# Out:
# False

# %% [markdown]
# %%html
# https://www.google.com/searchbyimage?&image_url=http://i.imgur.com/njJkLm1.png

# %%
# r.text
print(r.url)
real_one = 'https://www.google.com/search?tbs=sbi:AMhZZisvNP0JiPXOabstteQ93xyfRs1xs23B0spHEjJHXyR7z03y--dAP0NAYt8GT-Ye02mBE68uZZND5Y7kil191b_1emsLmLpE6FQOu7mUt5waD0rDpbANZR_1hbZWXGCYUdQnkn-y58X_10F4DLjt3aXH3ROhEscPSYnW1AVJq5RWDR66TlZGc00uLrP3mdjlB8iNcislD1xLJv3wFhO75lbF9DY_1DOvm9-YhAS2FZaog7Y9HPhZ09hWdbWwvN8ElnGtkOLXJb9-TlRea9_1akUcuP6vLV6rAQld6DwdseeSWUirjrEQfjaJhDQJKcKta3KXrPkREKNnpdE9ThVjHJgRA_119TOTffm44U2mFY8oCIs9Yr1UAqLGYIDDayJi3sBXwMQlnRT3s3RGiYigPGnsNwSTI3PCZLc1ex8POK3bgNfni7NmDi0GVFwiCQy9QISfF5WMjsprlEu8Ztwa0y-EsTcdQCCPW6lk5E7RPSE3vAcFJK3tX1ygsEvBZqjs813bupgIWCRgl63SUJfpOCuKtuR5WkoaQmzuLsRn9tT0CSOL48aYlpr7PhwBpzSHy6fsSGspgJKuNgTqd9qTif4SuW0bZXC7b5R7m3nAVU7KYDeaAINp6FgOMMY-zHymud5HYfN5FKWixImSiI5iWHUOQMk90Vd4epUICUPKW4aPxAPakHTqANIN8t_1XaOhx65IoLyYGySfY8_1o-UnBWvBbCzBtiu8xx5a3OB1u9-iyyDolbwPe5wfceGnrkCCG3hxzXMJRM6oQ8leJmN7_1whLMsMZGttAeG2nwQI_1y6feFnUerCPMDfFVnZ96NH1a_1BRbYsxlJpdziflE5pY2UPt-YXH2e6u7FEeNwjXTMsUT-TMsreKUrcCiWtBu_1Obv_18SUcTsZqIEM9ZyWc0KUjgv-WaG0DqVoZ2Oem4c4WPF3uTy_1mWxgH79nWn9t48CtUmP36d5pzVwV9bw0WLmwWjcZ7dWJg3ontmWIqbGehvYbBSBEOFxQYkT-89SwPPbfyXU8LieKO_15OGPNhGGgI0girpHIl9qtZ7zNRoix7qHoZn8MbpXGbbmH9Yg4V6VEZ8T-muMpPqoEaDup5vpOCUrBXp-LME0JFdmRmYj6rf-Q1xFnwg-7qgg24SBlhGUYmgL-C3M3mB9XiKhfhiyGz_11mOylLd7GSTC9kSTmTiTWkFNJKG5Z1MEwGKuBylsUP2cf_1Si2hWbTFwqMAAxjxqeXtr3AdoUM1CBkg-jx4MjC4hce_1BnVVCkE3Ol29FM6c8sC8am_1jAH7NadzV2_1mW-GrKhxh4U1RZvn8Yx7Ik6-eqmiIqUI3rUOHgEHQhWDAqNDjLzNSO-jSXLjszmAh1xINPaMbc_1YEuShDAR8Al8Hu8K0BFoRaudR6kSBrY'
fixed = r.url.replace('webhp', 'search')
r = requests.get(real_one)
r.url
# Out:
# https://www.google.com/webhp?tbs=sbi:AMhZZiulF1QDBg89QvbkoQBW8J_18jwZC8Gqm0jGDpKZr5TIgKZ4Q7mB68FgQFqfwjhR9wc3h1vev5y9MScNWBizcESMeZj5D2g
# ...

# %%
def render():
    from IPython.display import display, HTML
    chart = HTML(r.text)
    # chart = charts.plot(...)
    display(chart)

render()
# Out:
# <!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="en"><head><meta content="Search the world's information, including webpages, images, videos and more. Google has many special features to help you find exactly what you're looking for." name="description"><meta content="noodp" name="robots"><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script>(function(){window.google={kEI:'_rU_WM6fHcPwjwOhtKDQBg',kEXPI:'750722,1351903,1352297,3700286,4029815,4031109,4032678,4036527,4038012,4039268,4043492,4045841,4048347,4052304,4062666,4065786,4067860,4068550,4068816,4069838,4069840,4071842,4072364,4072602,4072775,4073405,4073728,4073959,4074349,4076095,4076931,4076999,4078430,4078438,4078457,4079083,4079105,4079442,4079623,4079894,4080167,4080629,4081037,4081039,4081264,4081487,4082217,4082618,4083030,4083280,4083476,4083514,4084097,4084
# ...

# %%
import selenium
from selenium.webdriver import Chrome

# %%
ff = Chrome()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /home/k/.local/lib/python3.5/site-packages/selenium/webdriver/common/service.py in start(self)
#      63                                             close_fds=platform.system() != 'Windows',
# ---> 64                                             stdout=self.log_file, stderr=self.log_file)
#      65         except TypeError:
#
# /home/k/anaconda3/lib/python3.5/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds)
#     946                                 errread, errwrite,
# --> 947                                 restore_signals, start_new_session)
#     948         except:
#
# ...

# %%
# %matplotlib inline
import cv2
import numpy as np
from matplotlib import pyplot as plt
 
img = cv2.imread('/home/k/Desktop/ferncanyon.jpg',0)
img2 = img.copy()
template = cv2.imread('/home/k/Desktop/ferncanyon.jpg',0)
w, h = template.shape[::-1]

# All the 6 methods for comparison in a list
methods = ['cv2.TM_CCOEFF', 'cv2.TM_CCOEFF_NORMED', 'cv2.TM_CCORR',
            'cv2.TM_CCORR_NORMED', 'cv2.TM_SQDIFF', 'cv2.TM_SQDIFF_NORMED']

for meth in methods:
    img = img2.copy()
    method = eval(meth)

    # Apply template Matching
    res = cv2.matchTemplate(img,template,method)
    min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(res)

    # If the method is TM_SQDIFF or TM_SQDIFF_NORMED, take minimum
    if method in [cv2.TM_SQDIFF, cv2.TM_SQDIFF_NORMED]:
        top_left = min_loc
    else:
        top_left = max_loc
        
    bottom_right = (top_left[0] + w, top_left[1] + h)

    cv2.rectangle(img,top_left, bottom_right, 255, 2)

    plt.subplot(121),plt.imshow(res,cmap = 'gray')
    plt.title('Matching Result'), plt.xticks([]), plt.yticks([])
    plt.subplot(122),plt.imshow(img,cmap = 'gray')
    plt.title('Detected Point'), plt.xticks([]), plt.yticks([])
    plt.suptitle(meth)
 
    plt.show()

# %%
image = cv2.imread('/home/k/Desktop/ferncanyon.jpg',0)

# %%
surf = cv2.xfeatures2d.SURF_create(400)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-cc299f9a702d> in <module>()
# ----> 1 surf = cv2.xfeatures2d.SURF_create(400)
#
# AttributeError: module 'cv2.cv2' has no attribute 'xfeatures2d'

# %%
gray_img = cv2.imread('/home/k/Desktop/ferncanyon.jpg')
#cv2.imshow('GoldenGate',gray_img)
hist = cv2.calcHist([gray_img],[0],None,[256],[0,256])
plt.hist(gray_img.ravel(),256,[0,256])
plt.title('Histogram for gray scale picture')
plt.show()

# %%
color = ('b','g','r')
for channel,col in enumerate(color):
    histr = cv2.calcHist([img],[channel],None,[256],[0,256])
    plt.plot(histr,color = col)
    plt.xlim([0,256])
plt.title('Histogram for color scale picture')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-21-41c69b27a478> in <module>()
#       1 color = ('b','g','r')
#       2 for channel,col in enumerate(color):
# ----> 3     histr = cv2.calcHist([img],[channel],None,[256],[0,256])
#       4     plt.plot(histr,color = col)
#       5     plt.xlim([0,256])
#
# error: /io/opencv/modules/imgproc/src/histogram.cpp:146: error: (-215) j < nimages in function histPrepareImages
