# %% [markdown]
# ```
# $.ajax({url: "http://api.randomuser.me",
#                     type: 'GET',
#                     data: {results: '5'},
#                     success: function(rsp){
#                        console.log(rsp.results);
#                        }
#                     error: function() {
#                         alert('error');
#                     }
#                    })
# ```
