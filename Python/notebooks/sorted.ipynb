# %%
llamas = [(3, 'a'), (1, 'b')]

# %%
llamas
# Out:
# [(3, 'a'), (1, 'b')]

# %%
sorted(llamas)
# Out:
# [(1, 'b'), (3, 'a')]

# %%
def helper(t):
    return t[1]

sorted(llamas, key=helper)
# Out:
# [(3, 'a'), (1, 'b')]

# %%
sorted(llamas, key=lambda t: t[1])
# Out:
# [(3, 'a'), (1, 'b')]

# %%
 y = ['aaa', 'bb', 'c']
    
sorted(y)
# Out:
# ['aaa', 'bb', 'c']

# %%
 y = ['aaa', 'bb', 'c']
    
sorted(y, key=len)
# Out:
# ['c', 'bb', 'aaa']
