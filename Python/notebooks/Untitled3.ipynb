# %%
animals = [1, 2, 3]

# %%
animals
# Out:
# [1, 2, 3]

# %%
animals[-1]
# Out:
# 3

# %%
mixer = [1, True, None, 'llamadog', 999, animals]

# %%
mixer
# Out:
# [1, True, None, 'llamadog', 999, [1, 2, 3]]

# %%
mixer[-3]
# Out:
# 'llamadog'

# %%
mixer[-3].upper()
# Out:
# 'LLAMADOG'

# %%
toothpaste = ['colgate']

# %%
type(toothpaste)
# Out:
# list

# %%
toothpaste.append(True)

# %%
toothpaste
# Out:
# ['colgate', True]

# %%
toothpaste.append(True)

# %%
toothpaste
# Out:
# ['colgate', True, True]

# %%
toothpaste[1] = False

# %%
toothpaste
# Out:
# ['colgate', False, True]

# %%
llama = 'llamas'

# %%
llama[:] = 'Z'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-bd9bad65a6ed> in <module>()
# ----> 1 llama[:] = 'Z'
#
# TypeError: 'str' object does not support item assignment

# %%
toothpaste
# Out:
# ['colgate', False, True]

# %%
toothpaste.remove('colgate')

# %%
toothpaste
# Out:
# [False, True]

# %%
toothpaste.pop()
# Out:
# True

# %%
toothpaste
# Out:
# [False]

# %%
toothpaste
# Out:
# [False]

# %%
toothpaste.append('Toms')

# %%
toothpaste
# Out:
# [False, 'Toms']

# %%
thing = toothpaste.pop()

# %%
thing
# Out:
# 'Toms'

# %%
toothpaste
# Out:
# [False]
