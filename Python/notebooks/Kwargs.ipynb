# %%
def combine(llamas, first=0, second=9):
    return first + second + len(str(llamas))

# %%
combine(9)
# Out:
# 10

# %%
combine(9, 9)
# Out:
# 19

# %%
combine(22, second=20, first=50)
# Out:
# 72
