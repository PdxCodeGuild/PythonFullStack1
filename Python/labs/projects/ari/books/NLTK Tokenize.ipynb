# %%
import nltk

# %%
def open_iliad():
    with open('iliad.txt', 'r') as iliad:
        text = iliad.read()
        
        return text

# %%
iliad = open_iliad().split()

# %%
len(iliad)
# Out:
# 155731

# %%
tokenized = nltk.Text(iliad)

# %%
# %matplotlib inline
tokenized.dispersion_plot(['water', 'fire', 'wind', 'earth'])

# %%
d = nltk.corpus.cmudict.dict()

# %%
d
# Out:
# {'comforting': [['K', 'AH1', 'M', 'F', 'ER0', 'T', 'IH0', 'NG']],
#  'kender': [['K', 'EH1', 'N', 'D', 'ER0']],
#  'surrealisms': [['S', 'ER0', 'IY1', 'L', 'IH0', 'Z', 'AH0', 'M', 'Z'],
#   ['S', 'ER0', 'IY1', 'AH0', 'L', 'IH2', 'Z', 'AH0', 'M', 'Z']],
#  'easy': [['IY1', 'Z', 'IY0']],
#  'bennison': [['B', 'EH1', 'N', 'IH0', 'S', 'AH0', 'N']],
#  'durnell': [['D', 'ER1', 'N', 'AH0', 'L']],
#  'klucevsek': [['K', 'L', 'UW0', 'S', 'EH1', 'V', 'S', 'EH0', 'K']],
#  'beerbower': [['B', 'IH1', 'R', 'B', 'OW0', 'ER0']],
#  '}close-brace': [['K', 'L', 'OW1', 'Z', 'B', 'R', 'EY1', 'S']],
#  'scams': [['S', 'K', 'AE1', 'M', 'Z']],
#  'explicit': [['IH0', 'K', 'S', 'P', 'L', 'IH1', 'S', 'AH0', 'T']],
#  'clucas': [['K', 'L', 'UW1', 'K', 'AH0', 'Z']],
#  'hallucinates': [['HH', 'AH0', 'L', 'UW1', 'S', 'AH0', 'N', 'EY0', 'T', 'S']],
#  'latella': [['L', 'AA0', 'T', 'EH1', 'L', 'AH0']],
#  'bridger': [['B', 'R', 'IH1', 'JH', 'ER0']],
#  "gleason's": [['G', 'L', 'IY1', 'S', 'AH0', 'N', 'Z']],
# ...

# %%
def extract_features(wordlist):
    wordlist = nltk.FreqDist(wordlist)
    word_features = wordlist.keys()
    return word_features

# %%
wf = extract_features(iliad)

# %%
wf
# Out:
# dict_keys(['husband,"', 'gathering', 'easy', 'gods."', 'everybody?"', 'singleness', 'that', 'men;', 'Enops', "'your", 'high-handed', 'foiled', 'gush', 'Jove', 'Diomed--The', 'XXIV', 'Thrasius,', 'himself--here', 'gleaming', 'piercer', 'settle', 'baths,', 'distribute', 'blame', 'lineage.', 'foments', 'were.', 'reported', 'haunt', 'give-and-take', 'counselled;', 'ploughman', 'entered', 'archery', 'thwarts', 'Argives,', 'dues,', 'anyone', 'slain', 'There', 'workmanship;', 'daring', 'wedding', 'Sarpedon;', 'Had', 'Surely', '"Alas,', 'theme', 'chide', 'rushes', 'evils,', 'many,', "Nestor's.", 'ageless', 'thought,', 'immortals', 'anxious', 'Gutenberg', "driver's", 'boy', 'hardest', 'tempting', 'sheaves', 'Vulcan', 'right-hand', 'surprised', 'quail', 'snake', 'water-meadows,', 'I--foremost', 'Unless', 'drive', 'walk', 'towns', 'displeased.', 'reared', 'heaven--many', 'mad', 'sharp', 'spears:', 'sown.', 'evermore."', 'wheel,', 'breast.', 'argue', 'strive', 'Laodameia.', 'menaced', 'bane', 't
# ...

# %%
def get_words():
    pass

# %%
tokenized.common_contexts(['flames'])

# %%
from nltk.sentiment.sentiment_analyzer import SentimentAnalyzer

# %%
il = " ".join(iliad)

# %%
il
